# %%
#Import library

import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#Download dataset dan disimpan pada folder /tmp

# !wget --no-check-certificate \
  https://dicodingacademy.blob.core.windows.net/picodiploma/ml_pemula_academy/rockpaperscissors.zip \
  -O /tmp/rockpaperscissors.zip
# Out:
# --2020-07-17 07:27:57--  https://dicodingacademy.blob.core.windows.net/picodiploma/ml_pemula_academy/rockpaperscissors.zip
# Resolving dicodingacademy.blob.core.windows.net (dicodingacademy.blob.core.windows.net)... 52.239.197.36
# Connecting to dicodingacademy.blob.core.windows.net (dicodingacademy.blob.core.windows.net)|52.239.197.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322873683 (308M) [application/zip]
# Saving to: ‘/tmp/rockpaperscissors.zip’
#
# /tmp/rockpapersciss 100%[===================>] 307.92M  7.07MB/s    in 48s
#
# 2020-07-17 07:28:46 (6.38 MB/s) - ‘/tmp/rockpaperscissors.zip’ saved [322873683/322873683]

# %%
#Import library dan extract dataset

import zipfile, os
local_zip = '/tmp/rockpaperscissors.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
#Cek isi file dari /tmp

os.listdir('/tmp')
# Out:
# ['rockpaperscissors', 'rockpaperscissors.zip', '__MACOSX']

# %%
#Cek isi file dari /tmp/rockpaperscissors

os.listdir('/tmp/rockpaperscissors')
# Out:
# ['rock', 'README_rpc-cv-images.txt', 'rps-cv-images', 'paper', 'scissors']

# %%
#Cek jumlah file dari /tmp/rockpaperscissors/rock

len(os.listdir('/tmp/rockpaperscissors/rock'))
# Out:
# 726

# %%
#Cek jumlah file dari /tmp/rockpaperscissors/paper

len(os.listdir('/tmp/rockpaperscissors/paper'))
# Out:
# 712

# %%
#Cek jumlah file dari /tmp/rockpaperscissors/scissors

len(os.listdir('/tmp/rockpaperscissors/scissors'))
# Out:
# 750

# %%
#Import library

from sklearn.model_selection import train_test_split

# %%
#Membuat direktori training dan validation

base_dir = '/tmp/rockpaperscissors'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

os.mkdir(train_dir)
os.mkdir(validation_dir)

# %%
#Cek direktori training

os.listdir('/tmp/rockpaperscissors/train')
# Out:
# []

# %%
#Cek direktori validation

os.listdir('/tmp/rockpaperscissors/validation')
# Out:
# []

# %%
#Membuat direktori rock, paper, dan scissors pada training dan validation

train_rock = os.path.join(train_dir, 'rock')
train_paper = os.path.join(train_dir, 'paper')
train_scissors = os.path.join(train_dir, 'scissors')

validation_rock = os.path.join(validation_dir, 'rock')
validation_paper = os.path.join(validation_dir, 'paper')
validation_scissors = os.path.join(validation_dir, 'scissors')

os.mkdir(train_rock)
os.mkdir(train_paper)
os.mkdir(train_scissors)

os.mkdir(validation_rock)
os.mkdir(validation_paper)
os.mkdir(validation_scissors)

# %%
#Cek direktori training rock

os.listdir('/tmp/rockpaperscissors/train/rock')
# Out:
# []

# %%
#Cek direktori training paper

os.listdir('/tmp/rockpaperscissors/train/paper')
# Out:
# []

# %%
#Cek direktori training scissors

os.listdir('/tmp/rockpaperscissors/train/scissors')
# Out:
# []

# %%
#Cek direktori validation rock

os.listdir('/tmp/rockpaperscissors/validation/rock')
# Out:
# []

# %%
#Cek direktori validation paper

os.listdir('/tmp/rockpaperscissors/validation/paper')
# Out:
# []

# %%
#Cek direktori validation scissors

os.listdir('/tmp/rockpaperscissors/validation/scissors')
# Out:
# []

# %%
#Membuat variabel dari direktori rock, paper, dan scissors

rock_dir = '/tmp/rockpaperscissors/rock'
paper_dir = '/tmp/rockpaperscissors/paper'
scissors_dir = '/tmp/rockpaperscissors/scissors'

# %%
#Cek jumlah file dari variabel rock

len(os.listdir(rock_dir))
# Out:
# 726

# %%
#Cek jumlah file dari variabel paper

len(os.listdir(paper_dir))
# Out:
# 712

# %%
#Cek jumlah file dari variabel scissors

len(os.listdir(scissors_dir))
# Out:
# 750

# %%
#Membagi data training dan data validation sebesar 40%

train_rock_dir, validation_rock_dir = train_test_split(os.listdir(rock_dir), test_size = 0.4)
train_paper_dir, validation_paper_dir = train_test_split(os.listdir(paper_dir), test_size = 0.4)
train_scissors_dir, validation_scissors_dir = train_test_split(os.listdir(scissors_dir), test_size = 0.4)

# %%
#Import library

import shutil

# %%
#Menyalin file dari hasil pembagian training dan validation ke direktori masing-masing

for i in train_rock_dir:
  shutil.copy(os.path.join(rock_dir, i), os.path.join(train_rock, i))
for i in train_paper_dir:
  shutil.copy(os.path.join(paper_dir, i), os.path.join(train_paper, i))
for i in train_scissors_dir:
  shutil.copy(os.path.join(scissors_dir, i), os.path.join(train_scissors, i))

for i in validation_rock_dir:
  shutil.copy(os.path.join(rock_dir, i), os.path.join(validation_rock, i))
for i in validation_paper_dir:
  shutil.copy(os.path.join(paper_dir, i), os.path.join(validation_paper, i))
for i in validation_scissors_dir:
  shutil.copy(os.path.join(scissors_dir, i), os.path.join(validation_scissors, i))

# %%
#Cek isi dari training rock

os.listdir('/tmp/rockpaperscissors/train/rock')
# Out:
# ['hAcc7l7XQ9EtxxfR.png',
#  'zkNTynOVx99Kr46m.png',
#  'GA6w6DqplIPDNDeO.png',
#  '8HKeT2oFz3gPSW0p.png',
#  'y57pFGvddZimmNu8.png',
#  'nQ7DM3VMBj0NdM0u.png',
#  '4RyeZiScDO5Z45oG.png',
#  'wZikdISRLJlJwp9q.png',
#  'Z1iNm9ej2ER2TGtC.png',
#  'mwbC6miMP5CXTp3a.png',
#  'Mwr4GgRRk6BgHDVL.png',
#  'bC8Fki1Na2rRSlBG.png',
#  'HWvrWXLQywNe1aCF.png',
#  'tGBAO9oyBYRD7XXS.png',
#  '96Sw16ZnG0zF8Qo0.png',
#  'QdUOXLvrrFZbV5G6.png',
#  'TLbqMqwDrww8CS0p.png',
#  'PFyOS0TL9gRsnYi8.png',
#  'F2MYeViv785ejIrb.png',
#  '7xID6kq32pdkEBIe.png',
#  'qNLvry2jUcwSulgu.png',
#  'Shr7grl23ISlh4Yu.png',
#  'rULPfRAFnmSQtUhh.png',
#  'O0YV4V0z2pe4kxwx.png',
#  'HY0UHs2e3ydpvynQ.png',
#  'HHXLX66BbEVNYl6W.png',
#  'zZRojXITRo7bAIRT.png',
#  'kcZfTQqKr8VaSjhk.png',
#  '5cJA6BncdVbygRNL.png',
#  'sCkuAnI0vDucXt7m.png',
#  'rBGSBjzYhvdPSDV0.png',
#  'IoVOalbQe90ghv9U.png',
#  'rGh56uZVxk2MZLWF.png',
#  'xxUPxq2BY6NvCmP2.png',
#  'PxixapAFqLmRaP6k.png',
#  'JxhewAxaOg3wB1gA.png',
#  '1e1VCnCEApnFh9Oo.png',
# ...

# %%
#Cek jumlah training rock

len(os.listdir('/tmp/rockpaperscissors/train/rock'))
# Out:
# 435

# %%
#Cek isi dari training paper

os.listdir('/tmp/rockpaperscissors/train/paper')
# Out:
# ['KPJ371erJ0RUKNAX.png',
#  'pVCqrp8S6Ze3DAI8.png',
#  'Qbn4RJqessetWPHR.png',
#  'YkZMyyS9fJdKmL3F.png',
#  'C9tAvywdtjDTnllg.png',
#  'WVfwcOw6nXcg4xER.png',
#  'fjITlTb11LELvo3e.png',
#  'UuF8mRQ3FDM6fOmp.png',
#  '7I1fABs6SL1T4MNb.png',
#  'QVIiXr87PkeldzZM.png',
#  'LpASHQ03atiBeyRw.png',
#  'eASnEW16rlMUPMf3.png',
#  'ul2wGK0NgJXs8mHv.png',
#  'CpDMCILKUN2AUA1A.png',
#  'OSEIPDjPzHw3gKjc.png',
#  'MnvVVMoqDmzrm5NJ.png',
#  'N4D5tleMLbP1Au5D.png',
#  'NLwrHPTaiNSMjHLX.png',
#  '8X1BUL9w2OMExPy5.png',
#  'DBriMZZSZtYea72l.png',
#  'ehzdlf5B1HtVgpRs.png',
#  'dZxpgHYRuQNv7T7A.png',
#  'Om6b4BvZS49QNNFV.png',
#  'n8IzyztMwnfa5rjf.png',
#  'mugG8B1m5Ra2aRgZ.png',
#  'v6wOWeRyh3Sv5BXo.png',
#  '0RA9rcrv8iVvuDDU.png',
#  'PZrfX01MvfB3oeyB.png',
#  'JsryGUQahbbNkrlP.png',
#  'xioDLxSWnSZ5sDbQ.png',
#  'a45DJKHJdnCFhX5X.png',
#  'OJpDyt2u6zzfoVP0.png',
#  'fPwDPzGZ5JeY0rb9.png',
#  'mUqkjFi6NBsHR7tf.png',
#  'Vly5xEFupx36kCcd.png',
#  'Z9vSGzBQ8YLOXQIX.png',
#  'XNUalPNmCkHhYk1i.png',
# ...

# %%
#Cek jumlah training paper

len(os.listdir('/tmp/rockpaperscissors/train/paper'))
# Out:
# 427

# %%
#Cek isi training scissors

os.listdir('/tmp/rockpaperscissors/train/scissors')
# Out:
# ['yxCsGCXdJ0UuGEol.png',
#  'yPDwuZYpXF1iWDVh.png',
#  'RtsIA3p963IFGi8t.png',
#  'xKyBoUZHpqSVqTLx.png',
#  'a6nlEYiU2vnnUcp3.png',
#  'w1NflQUWVQmFdZdI.png',
#  'ZzIlyDP6opy9ifkB.png',
#  'FSJKz70kgKxJyjjl.png',
#  '2TAGoXw7yaK0bXBu.png',
#  'oxU5O3n839QvrOGu.png',
#  'b6laDVaqf5K3aQvH.png',
#  'sC3hanWBPaeGV4xg.png',
#  'ZGPpmBaEH8F0qXzI.png',
#  'ksWe2SZsjOoLAzf5.png',
#  'Y803FUXqbDOwGm0K.png',
#  '7Zb3QM9tznboKuQE.png',
#  'sVmVaYH9SUDDI6y4.png',
#  'BpCDUnGgYRS4T8IG.png',
#  'hAb9a8XAGVZnLM6m.png',
#  'tpIDNu7Hg6k1SZef.png',
#  'hly8CYYf6AiQucXm.png',
#  'dxFGJyDhnNu3iOmm.png',
#  'yiOfEmSzPhjaYDwH.png',
#  'jui5QU0jWOCKf8hW.png',
#  'Bd18RfxcJr6O5n6j.png',
#  'Ep0yJCcioRpgZquy.png',
#  '277q9TUTAsBAbTCj.png',
#  'tTOLtCt5p5upFetg.png',
#  'XwaRRl8CwYMJKx95.png',
#  'SiIASaSafeaodwOd.png',
#  'jL3CMVgsLdWznnKe.png',
#  '1jKhi65BPTLXnUI6.png',
#  'Z1leFM4TO5u2eSaI.png',
#  'VQI4ru8aVkvWIHT4.png',
#  'wjpTy95PqKpcRg9o.png',
#  'AgfZ2awwDPr3d50b.png',
#  '3kVoftgTNdDcvPPY.png',
# ...

# %%
#Cek jumlah training scissors

len(os.listdir('/tmp/rockpaperscissors/train/scissors'))
# Out:
# 450

# %%
#Cek isi validation rock

os.listdir('/tmp/rockpaperscissors/validation/rock')
# Out:
# ['MLmBabhqRs9Gxec0.png',
#  'VxODCZVhiNVfWsLj.png',
#  'vXU1VEpTIJDKa6kg.png',
#  'c1rdxANL8E7yG3ZI.png',
#  'xPuMzxjXPJpLuCsl.png',
#  'E4kPnJ376NIwG4Mh.png',
#  '1wk2Hl1Ih9guOwx6.png',
#  '0NDYNEoDui7o64gU.png',
#  'ZPRYcDY3SAyZigkB.png',
#  'XqR9QAFi9qQMUdw2.png',
#  'X4UIuiTnzUP68r86.png',
#  'poJARbX3gvvFDPXQ.png',
#  'iDKbsfPFabN9bUKT.png',
#  'gutk3kRhu9AfjYWQ.png',
#  'FFAcRoW2ejkNNheZ.png',
#  '3XNPuMFoaFCfRCVb.png',
#  'yga4KN1EfpYG2u9w.png',
#  'xc9iqz3P8tF5YdCG.png',
#  '5EEdNZWT8M9PThPB.png',
#  'bqpOIN5gUl0r6vIS.png',
#  'DBvjNfYD7dv2f3gw.png',
#  'xMzUrLkx9vIWWwZU.png',
#  'xH9uXlr7ev4rhwf2.png',
#  '9TeUwuSOgtGgewNL.png',
#  'n3ryKsLTPcGhpW6S.png',
#  'pU5fol2HJ1fxobLd.png',
#  'xqCLaIfsVBFNf63M.png',
#  'yhdKczrnPdXbTjZc.png',
#  'Qm3EaazkLKL9qJJz.png',
#  'y0ZTIzS3rpKagERb.png',
#  '2nSUlcvPf1DOCo1j.png',
#  'k6r5z3dMsqo2H6hk.png',
#  '9sJrWSSurvaNb8FW.png',
#  'I8DyB4yRN0Q8voWp.png',
#  'ZM4bG569OHTj1XMT.png',
#  '7O4sybfz26sg4yrF.png',
#  '337ARHTZmhCSkoEM.png',
# ...

# %%
#Cek jumlah validation rock

len(os.listdir('/tmp/rockpaperscissors/validation/rock'))
# Out:
# 291

# %%
#Cek isi validation paper

os.listdir('/tmp/rockpaperscissors/validation/paper')
# Out:
# ['ac0j8jCfz8hwpY0o.png',
#  'qGf97ZWPmGYzlTpo.png',
#  'ukOGooYiFOfJHNrx.png',
#  'UJdZdj6nyFRHVFEg.png',
#  'nnf5jELXQuneoejn.png',
#  'yPnREvUeAGYRKi7V.png',
#  'p81Lb4bD6fEvkSQ0.png',
#  'qM0f6IJPDfLRpo1d.png',
#  'CwFaCN3ykqwQ6KZV.png',
#  'Ze6bn38U5XECyORF.png',
#  'xJAZ3PewpLYs4ogR.png',
#  '1fKclJk4eBWOQSR1.png',
#  'ZGQV7rFVePreAdOe.png',
#  '7ZGsbIMypDIEZxR0.png',
#  'UHyVkisiFMmasl7b.png',
#  'av2NxK494nd72Q13.png',
#  'Y8kfG3f6KJa1YJPA.png',
#  'ZGLUqWHjarBly23b.png',
#  '9zfyVkUcku0qc4Gu.png',
#  'fiX6rjBt5qHGMsjc.png',
#  'pMQfFsmXAu2xZuUv.png',
#  '6ycslJxTsTjZc5H2.png',
#  'uoYuyEHvVLrOOmqW.png',
#  'MLrUGD1graoSw2c5.png',
#  'SjE9MULuPPnbplHT.png',
#  '9xyvz1JbPwNqtLgH.png',
#  'gR2aEiEX8CzCtyBN.png',
#  'QqPSoi6Vj2Vbua3V.png',
#  'Lmx5I567tGyQ9HYi.png',
#  'yaRRMcZS7JJ3xLK1.png',
#  '4Pir885YNPXiRs0R.png',
#  'D9nbrQLDSgDMNh3G.png',
#  'y9DoLrI4Hlh2EUts.png',
#  'TYjJigXjEyiVntzx.png',
#  '0eqArS2GgsBeqgSn.png',
#  'KGiyDw5Ryx3WjjSZ.png',
#  'xsM5n0KOqwb5R58V.png',
# ...

# %%
#Cek jumlah validation paper

len(os.listdir('/tmp/rockpaperscissors/validation/paper'))
# Out:
# 285

# %%
#Cek isi validation scissors

os.listdir('/tmp/rockpaperscissors/validation/scissors')
# Out:
# ['4hvoLYY28SGuZCEI.png',
#  'OWzxS6m9SGpk1bnY.png',
#  'kY0Q7raIkxwCCOk2.png',
#  'WYOb0YuOVCMs7ebJ.png',
#  'uJ286TPihhYw3Y3S.png',
#  'YXMdBr7G2GS6sN1v.png',
#  'ZCr3PjDcttbKRAAW.png',
#  'R8EezCr0SD3e39T0.png',
#  '8ei3rSl89D6W8Tav.png',
#  'ejrBEOeknHrk4kCi.png',
#  'PJxEXjRb0K0Mpgsz.png',
#  '7SOrAw5PvJghnwuq.png',
#  'gLvAPtEJW1Ff5KLX.png',
#  'wJNyEIqVDFH8bx5h.png',
#  '6CyIuv1pvHDwTWmR.png',
#  'U6bMgGB3gf9rMBvE.png',
#  'mxyADQuZCMwE1Nv5.png',
#  'dowAehk6HVomDGpw.png',
#  'KSNET1XTWbrg5Rcz.png',
#  'w58UIOAxkjM2L3AO.png',
#  'WoS4fluqoRRsfjle.png',
#  'm7ELYBy0O4wx0YqJ.png',
#  'kM3ks8HWMjhbBPWU.png',
#  'TTISkHEEyMVpUk5B.png',
#  'JSDICtLrQIEXhPy5.png',
#  'F4iIoT06hTWSuSs2.png',
#  'HGhHQ3uNh7XFl2ar.png',
#  'e8hlT6glM2V2RYgN.png',
#  '7LFhnAZBWmtcMqDM.png',
#  'VOgDVSfapx23t5tA.png',
#  '7A1YTmfZsbSdxPKy.png',
#  'TNOQ2IEy4C6LBSD1.png',
#  'mfrG6yVMg6CEzoCN.png',
#  'VrHis8ru9xXA5Lqh.png',
#  '2fxAdPTgrVIoITsL.png',
#  'JWz75J1U5sGr1FH2.png',
#  'dnXr5NzZKqzg8VgI.png',
# ...

# %%
#Cek jumlah validation scissors

len(os.listdir('/tmp/rockpaperscissors/validation/scissors'))
# Out:
# 300

# %%
#Membuat image data generator (proses augmentasi gambar) dengan beberapa penyesuaian

train_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 20,
    horizontal_flip = True,
    shear_range = 0.2,
    fill_mode = 'nearest'
)

test_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 20,
    horizontal_flip = True,
    shear_range = 0.2,
    fill_mode = 'nearest'
)

# %%
#Mempersiapkan data dengan flowfromrdirectory dengan beberapa penyesuaian

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (150, 150),
    batch_size = 32,
    class_mode = 'categorical'
)

validation_generator = test_datagen.flow_from_directory(
    validation_dir,
    target_size = (150, 150),
    batch_size = 32,
    class_mode = 'categorical'
)
# Out:
# Found 1312 images belonging to 3 classes.
# Found 876 images belonging to 3 classes.

# %%
#Membuat model arsitektur dari CNN

model = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = (150, 150, 3)),
        tf.keras.layers.MaxPooling2D(2, 2),

        tf.keras.layers.Conv2D(64, (3, 3), activation = 'relu'),
        tf.keras.layers.MaxPooling2D(2, 2),

        tf.keras.layers.Conv2D(128, (3, 3), activation = 'relu'),
        tf.keras.layers.MaxPooling2D(2, 2),

        tf.keras.layers.Conv2D(128, (3, 3), activation = 'relu'),
        tf.keras.layers.MaxPooling2D(2, 2),

        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512, activation = 'relu'),
        tf.keras.layers.Dense(3, activation = 'softmax')
])

# %%
#Compile model dengan categoricalcrossentropy, optimizer adam, dan menghitung akurasi

model.compile(loss = tf.keras.losses.CategoricalCrossentropy(),
              optimizer = tf.optimizers.Adam(),
              metrics = ['accuracy'])

# %%
#Melatih model dengan method fit

model.fit(
    train_generator,
    steps_per_epoch = 25,
    epochs = 20,
    validation_data = validation_generator,
    validation_steps = 5,
    verbose =2
)
# Out:
# Epoch 1/20
# 25/25 - 6s - loss: 0.9608 - accuracy: 0.5238 - val_loss: 0.7230 - val_accuracy: 0.7312
# Epoch 2/20
# 25/25 - 7s - loss: 0.5051 - accuracy: 0.8138 - val_loss: 0.3390 - val_accuracy: 0.8750
# Epoch 3/20
# 25/25 - 7s - loss: 0.2513 - accuracy: 0.9050 - val_loss: 0.1842 - val_accuracy: 0.9312
# Epoch 4/20
# 25/25 - 6s - loss: 0.2538 - accuracy: 0.9112 - val_loss: 0.3400 - val_accuracy: 0.8875
# Epoch 5/20
# 25/25 - 7s - loss: 0.2174 - accuracy: 0.9225 - val_loss: 0.1890 - val_accuracy: 0.9500
# Epoch 6/20
# 25/25 - 7s - loss: 0.2312 - accuracy: 0.9187 - val_loss: 0.2607 - val_accuracy: 0.9000
# Epoch 7/20
# 25/25 - 7s - loss: 0.1891 - accuracy: 0.9325 - val_loss: 0.1626 - val_accuracy: 0.9500
# Epoch 8/20
# 25/25 - 6s - loss: 0.1482 - accuracy: 0.9563 - val_loss: 0.1297 - val_accuracy: 0.9625
# Epoch 9/20
# 25/25 - 6s - loss: 0.1325 - accuracy: 0.9563 - val_loss: 0.1163 - val_accuracy: 0.9375
# Epoch 10/20
# ...

# %%
#Penggunaan model dengan memasukkan gambar

import numpy as np
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path, target_size = (150, 150))
  imgplot = plt.show(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 32)

  print(fn)
  if classes[0, 1] != 0:
    print('rock')
  elif classes[0, 0] != 0:
    print('paper')
  else:
    print('scissors')
# Out:
# Using TensorFlow backend.
#      <input type="file" id="files-c541111e-9df9-4ecf-a31c-4c75c7f5cd45" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c541111e-9df9-4ecf-a31c-4c75c7f5cd45">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kertas.jpeg to kertas.jpeg
# kertas.jpeg
# paper

# %%
#Penggunaan model dengan memasukkan gambar

import numpy as np
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path, target_size = (150, 150))
  imgplot = plt.show(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 32)

  print(fn)
  
  if classes[0,0]!=0:
    print('paper')
  elif classes[0,1]!=0:
    print('rock')
  else:
    print('scissors')
# Out:
#      <input type="file" id="files-53ca29cd-f0a9-4483-accc-81dcb725675c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-53ca29cd-f0a9-4483-accc-81dcb725675c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving scissors2.png to scissors2.png
# scissors2.png
# scissors

# %%
#Penggunaan model dengan memasukkan gambar

import numpy as np
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path, target_size = (150, 150))
  imgplot = plt.show(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 32)

  print(fn)
  if classes[0][0] == 1:
    print('paper')
  elif classes[0][1] == 1:
    print('rock')
  elif classes[0][2] == 1:
    print('scissor')
# Out:
#      <input type="file" id="files-b6c717b4-be13-4f14-ba28-d095a41992ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b6c717b4-be13-4f14-ba28-d095a41992ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving rock2.png to rock2 (1).png
# rock2.png
# rock

# %%
print(train_generator.class_indices)
# Out:
# {'paper': 0, 'rock': 1, 'scissors': 2}
